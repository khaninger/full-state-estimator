# %%
import matplotlib.pyplot as plt
import numpy as np
import rospy
import pickle
plt_dpi = 200

# %%
# Dict return, simple estimate plotter

trajs = ['data/ur_vertical_2.pkl']
    
skip = 10
ind = 3

fig = plt.plot(figsize=(8,8), dpi=plt_dpi)

for traj in trajs:
    with open(traj1, 'rb') as f:
        res = pickle.load(f)
        t = np.array([range(skip,num_pts)]).squeeze()/500.
        num_pts = res['q'].shape[1]
        dq = res['true_vel']
        dq_est = res['dq']
        plt.plot(t, dq_est[ind,skip:].T, 'r')
        plt.plot(t, dq[ind,skip:].T, 'k')

plt.grid(True)
plt.xlabel('Time (sec)')
plt.tight_layout()
# Out:
# dict_keys(['q', 'dq', 'xi', 'f_ee_obs', 'contact_1_force', 'contact_1_disp', 'contact_1_pt', 'contact_1_pos', 'contact_1_rest', 'contact_1_stiff', 'true_pos', 'true_vel', 'f_ee', 'input'])

# %%
# Plotting the estimated force, observer force, measured force

#traj = 'data/ur_vertical_3_stiff.pkl' # estimating stiffness online
traj = 'data/ur_vertical_2.pkl'
with open(traj, 'rb') as f:
    res1 = pickle.load(f)

#traj = 'data/ur_vertical_3_offline.pkl' # all fit parameters
#traj = 'data/ur_vertical_3.pkl' # all fit parameters
with open(traj, 'rb') as f:
    res2 = pickle.load(f)

#states = res1['states']
f_ee = res1['f_ee']

stiff = res1['contact_1_stiff']
f_ee_obs_stiff = res1['f_ee_obs']


f_ee[0,:] *= -1
f_ee[1,:] *= -1    

fig, axs = plt.subplots(3,1,figsize=(8,8), gridspec_kw={'height_ratios': [1, 1, 2]}, dpi=plt_dpi)
t = np.array([range(f_ee.shape[1])]).squeeze()/500.
time = t#range(0,5000)

for ind, ax in enumerate(axs):
    axs[ind].plot(t, f_ee[ind], 'k', label="Measured force")
    #axs[ind].plot(t, f_ee_mo[ind], 'b', label= "Momentum observer")
    axs[ind].plot(t, f_ee_obs_stiff[ind], 'r', label= "Online estimate stiff")
    axs[ind].plot(t, f_ee_obs_off[ind], 'g', label= "Offline fit params")
    axs[ind].grid(True)
    axs[ind].set_xlim([t[0],t[-1]])
axs[0].legend() 
axs[0].set_ylim([-55,35])
axs[1].set_ylim([-55,35])
axs[2].set_ylim([-125,35])
axs[0].set_ylabel('X Force (N)')
axs[1].set_ylabel('Y Force (N)')
axs[2].set_ylabel('Z Force (N)')

#plt.xlabel('Force (N)')
#fig.text(0.04, 0.5, 'Force (N)', va='center', rotation='vertical')
plt.xlabel('Time (sec)')
plt.tight_layout()
#plt.savefig('figs/force_comparison.pdf')

plt.figure(figsize=(8,3), dpi=plt_dpi)
time = range(2400, 7*500+200)
t = np.array([time]).squeeze()/500.

ind = 2
plt.plot(t, f_ee[ind,time], 'k', label="Measured force")
plt.plot(t, f_ee_mo[ind,time], 'b', label= "Momentum observer")
plt.plot(t, f_ee_obs_stiff[ind,time], 'r', label= "Online estimate stiff")
plt.plot(t, f_ee_obs_off[ind,time], 'g', label= "Offline fit params")
plt.grid(True)
plt.xlim([t[0],t[-1]])
plt.xlabel('Time (sec)')
plt.ylabel('Z Force (N)')
plt.show()
plt.tight_layout()
plt.savefig('figs/force_comparison_zoom.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 29>()
#      31 #axs[ind].plot(t, f_ee_mo[ind], 'b', label= "Momentum observer")
#      32 axs[ind].plot(t, f_ee_obs_stiff[ind], 'r', label= "Online estimate stiff")
# ---> 33 axs[ind].plot(t, f_ee_obs_off[ind], 'g', label= "Offline fit params")
#      34 axs[ind].grid(True)
#      35 axs[ind].set_xlim([t[0],t[-1]])
#
# NameError: name 'f_ee_obs_off' is not defined

# %%
## Comparing stiffness estimates

#traj = 'data/ur_vertical_3_stiff.pkl'
traj = 'data/ur_vertical_3.pkl'
    
with open(traj, 'rb') as f:
    states, _, _, x_ees, stiff, f_ee_mom_obs, f_ee_obs_stiff, f_ee, _, _ = pickle.load(f)

N = f_ee.shape[1]

# LS estimate of real stiffness
f_ee_w = np.zeros((3, N))
x_reg = np.ones((4,N))

for i in range(N):
    f_ee_w[:,i] = x_ees[i][1]@f_ee[:,i]
    x_reg[:3,i] = x_ees[i][0].squeeze()
    #print(x_reg[:,i])
Kx, _, _, _ = np.linalg.lstsq(x_reg[[0,-1],:].T, f_ee_w[0].T, rcond=None)
Ky, _, _, _ = np.linalg.lstsq(x_reg[[1,-1],:].T, f_ee_w[1].T, rcond=None)
Kz, _, _, _ = np.linalg.lstsq(x_reg[2:,:].T, f_ee_w[2].T, rcond=None)
print(Kx, Ky, Kz)

# Online moving-average first difference estimate
K_online = np.zeros((3,N))
offset = 100
for i in range(N-offset):
    K_online[:,i] = abs((f_ee_mom_obs[:,i+offset]-f_ee[:,i]))/np.array(abs((x_reg[:3,i+offset]-x_reg[:3, i]))).clip(min=5e-4)

# Value estimated by the offline optimization in diff env prim
Kx_offline = 7.3e-7
Ky_offline = 7.1e-6
Kz_offline = 28819.3

t = np.array([range(f_ee.shape[1])]).squeeze()/500.

fig = plt.figure(figsize=(7,3), dpi=plt_dpi)
scale = 1000
plt.plot(t[[0, -1]], [-Kz[0]/scale, -Kz[0]/scale], 'k', label="Least-squares from EE forces")
plt.plot(t, K_online[2]/scale, 'b', label= "First diff estimate w/ mom. obs")
plt.plot(t, -stiff[2]/scale, 'r', label= "EKF estimate")
plt.plot(t[[0, -1]], [Kz_offline/scale, Kz_offline/scale], 'g', label= "Offline fit stiffness")

plt.ylim((-2, 90))
plt.xlim(t[[0,-1]])
plt.grid(True)

plt.ylabel("Stiffness (N/mm)")
plt.xlabel("Time (sec)")
plt.legend()
plt.tight_layout()
plt.savefig('figs/stiffness.pdf')

fig, axs = plt.subplots(1,1,figsize=(7,2), dpi=plt_dpi)
scale = 1000
axs.plot(t, K_online[0]/scale, 'r', label= "Mom. obs, x")
axs.plot(t, -stiff[0]/scale, 'r', label= "EKF, x")
axs.plot(t, K_online[1]/scale, 'g:', label= "Mom. obs, y")
axs.plot(t, -stiff[1]/scale, 'g', label= "Mom. obs, y")
axs.set_ylabel("Stiffness (N/mm)")
axs.set_xlim(t[[0,-1]])
axs.grid(True)
axs.legend()
plt.xlabel("Time (sec)")
plt.savefig('figs/stiffness_xy.pdf')


fig, axs = plt.subplots(1,1,figsize=(7,2), dpi=plt_dpi)
scale = 1000

axs.plot(t, x_reg[0]-x_reg[0,0], 'r', label= "x")
axs.plot(t, x_reg[1]-x_reg[1,0], 'g', label= "y")
axs.plot(t, x_reg[2]-x_reg[2,0], 'b', label= "z")
axs.set_ylabel('Position (m)')
#plt.ylim((-2, 60))
axs.set_xlim(t[[0,-1]])
axs.grid(True)
axs.legend()
plt.xlabel("Time (sec)")
plt.show()
plt.tight_layout()

plt.savefig('figs/stiffness_motion.pdf')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [17], in <cell line: 15>()
#      13 x_reg = np.ones((4,N))
#      15 for i in range(N):
# ---> 16     f_ee_w[:,i] = x_ees[i][1]@f_ee[:,i]
#      17     x_reg[:3,i] = x_ees[i][0].squeeze()
#      18     #print(x_reg[:,i])
#
# IndexError: list index out of range

# %%
# Plotting the positoin and orientation of the robot and the estimated contact point
#%matplotlib
#traj = 'data/racer_rotate_long_4.pkl'
traj = 'data/ur_rotate_stiff_1.pkl'

rest_pos = rospy.get_param('contact_1_rest', [0.0, 0.0, 0.0]) 
#stiff = rospy.get_param('contact_1_stiff', [0.0, 0.0, 0.0]) 
scale = 0.02
scales = 1e-4#3e-6

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(projection="3d")
ax.set_box_aspect(aspect = (2,2,1))
with open(traj, 'rb') as f:
    _, _, x_is, x_ees, stiffs = pickle.load(f)[:5]

num_pts = x_is.shape[1]
pos_last = x_ees[0][0]
min_dist = 0.005
cmap = plt.get_cmap('plasma')
for i, (xi, xee, stiff) in enumerate(zip(x_is.T, x_ees, stiffs.T)):
    p = np.array(xee[0]).flatten()
    o = np.array(xee[1])
    if np.linalg.norm(p[:3] - pos_last[:3]) < min_dist:
        continue
    else:
        pos_last = p
    x = np.array(o[0,:])
    y = np.array(o[1,:])
    z = np.array(o[2,:])
    xs = o@stiff
    
    ax.plot([p[0], p[0]+scale*x[0]],
            [p[1], p[1]+scale*x[1]],
            [p[2], p[2]+scale*x[2]],
            'r', linewidth=2)
    ax.plot([p[0], p[0]+scale*y[0]],
            [p[1], p[1]+scale*y[1]],
            [p[2], p[2]+scale*y[2]],
            'g', linewidth=2)
    ax.plot([p[0], p[0]+scale*z[0]],
            [p[1], p[1]+scale*z[1]],
            [p[2], p[2]+scale*z[2]],
            'b', linewidth=2)
    #h_cs = ax.plot([xi[0], xi[0]-scales*xs[0]],
    #        [xi[1], xi[1]-scales*xs[1]],
    #        [xi[2], xi[2]-scales*xs[2]],
    #        color = cmap(float(i)/num_pts), linewidth=2)[0]
    h_ee = ax.plot(p[0], p[1], p[2], c = 'k', marker = 'o', ms = 5, label='TCP')[0]
    
    h_c1 = ax.plot(xi[0], xi[1], xi[2], c = 'r', marker = 'o', ms = 10, label='Estimated contact')[0]
h_rp1 = ax.plot(rest_pos[0], rest_pos[1], rest_pos[2], c= 'b',  marker = 'o', ms = 10, label='Estimated rest position')[0]
plt.tight_layout()
plt.xlabel('x (meter)')
plt.ylabel('y')
ax.view_init(elev= 10., azim=10.)
plt.legend(handles=[h_ee, h_c1, h_rp1],labels=['TCP pose', 'Contact point x_1', 'Rest position x_1^o'], loc='center left')
plt.subplots_adjust(left=-0.11, right=1.11, bottom=0.0, top=1)

plt.savefig('figs/offline_center.pdf')
plt.show()

# %%
# Plotting the estimated force, observer force, measured force

#traj = 'data/ur_rotate_stiff_2_geom.pkl'
traj = 'data/ur_rotate_stiff_2.pkl'

#traj = 'data/ur_rotate_3.pkl'
with open(traj, 'rb') as f:
    _, _, contact_pts, x_ees, stiff, _, f_ee_obs_stiff, f_ee, true_pos, true_vel = pickle.load(f)

poss = []
contact_pts = np.array(contact_pts)

for contact_pt, x_ee in zip(contact_pts.T, x_ees):
    pt = x_ee[1].T@(contact_pt - np.array(x_ee[0]).squeeze())
    poss.append(pt)
poss = np.array(poss)

t = np.array([range(f_ee.shape[1])]).squeeze()/500.
time = t#range(0,5000)

plt.figure(figsize=(4,3), dpi = plt_dpi)
plt.plot(t, contact_pts[0,:], 'r', label="EKF estimate, x")


x0 = [0.559, 0.241, -0.06]
plt.plot([t[0],t[-1]], [x0[0], x0[0]], 'r:', label="Offline estimate, x")
plt.plot([t[0],t[-1]], [x0[1], x0[1]], 'g:')
plt.plot([t[0],t[-1]], [x0[2], x0[2]], 'b:')


plt.plot(t, contact_pts[1,:], 'g', label="y")
plt.plot(t, contact_pts[2,:], 'b', label="z")

#plt.plot(t, contact_pts.T, label="Contact Points")
#plt.plot(t, poss[:,0], 'r', label="Contact Points")
#plt.plot(t, poss[:,1], 'g', label="Contact Points")
#plt.plot(t, poss[:,2], 'b', label="Contact Points")

#for ind, ax in enumerate(axs):
    #axs[ind].plot(t, f_ee_mo[ind], 'b', label= "Momentum observer")
    #axs[ind].plot(t, f_ee_obs_stiff[ind], 'r', label= "Online estimate stiff")
    #axs[ind].plot(t, f_ee_obs_off[ind], 'g', label= "Offline fit params")
    #axs[ind].grid(True)
    #axs[ind].set_xlim([t[0],t[-1]])
#axs[0].legend() 
#axs[0].set_ylim([-55,35])
#axs[1].set_ylim([-55,35])
#axs[2].set_ylim([-125,35])
#axs[0].set_ylabel('X Force (N)')
#axs[1].set_ylabel('Y Force (N)')
#axs[2].set_ylabel('Z Force (N)')

plt.ylabel('Position (m)')
plt.legend(loc='lower right')
plt.grid(True)
plt.xlabel('Time (sec)')
plt.xlim(t[0],t[-1])
plt.tight_layout()
plt.savefig('figs/online_center.pdf')

# %%
# Plotting the estimated stiffness in rotation
traj = 'data/ur_rotate_stiff_2.pkl'
#traj = 'data/ur_rotate_2.pkl'
with open(traj, 'rb') as f:
    states, _, _, x_ees, stiff, f_ee_mom_obs, f_ee_obs_stiff, f_ee, _, _ = pickle.load(f)

N = f_ee.shape[1]

t = np.array([range(f_ee.shape[1])]).squeeze()/500.

Kz_offline = 670.5
Kz = 670.5

fig = plt.figure(figsize=(4,3), dpi=plt_dpi)
scale = 1000

plt.plot(t, stiff[2]/scale, 'b', label= "EKF estimate, x")
plt.plot(t, stiff[1]/scale, 'g', label= "EKF estimate, y")
plt.plot(t, stiff[0]/scale, 'r', label= "EKF estimate, z")

#plt.ylim((-2, 60))
plt.xlim(t[[0,-1]])
plt.grid(True)

plt.ylabel("Stiffness (N/mm)")
plt.xlabel("Time (sec)")
plt.legend()
plt.tight_layout()
plt.savefig('figs/rotate_stiffness.pdf')
